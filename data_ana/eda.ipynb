# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/home/user/Desktop/review/results/eda/1216_1545/vocab.csv',
                usecols=['word', 'char_count'])
df.head()
# Out:
#   word  char_count
# 0    0           1
# 1  0,5           3
# 2  0,8           3
# 3   00           2
# 4   01           2

# %%
f = open('data_loader/test1.json')
data = json.load(f)
result =  pd.json_normalize(data, ['id', 'text'], 'labels')
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_27369/3213112646.py in <module>
# ----> 1 f = open('data_loader/test1.json')
#       2 data = json.load(f)
#       3 result =  pd.json_normalize(data, ['id', 'text'], 'labels')
#       4 print(result)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_loader/test1.json'

# %%
data = [
    {
        "state": "Florida",
        "shortname": "FL",
        "info": {"governor": "Rick Scott"},
        "counties": [
            {"name": "Dade", "population": 12345},
            {"name": "Broward", "population": 40000},
            {"name": "Palm Beach", "population": 60000},
        ],
    },
    {
        "state": "Ohio",
        "shortname": "OH",
        "info": {"governor": "John Kasich"},
        "counties": [
            {"name": "Summit", "population": 1234},
            {"name": "Cuyahoga", "population": 1337},
        ],
    },
]

import pandas as pd
# for i, x in enumerate(data):
#     x = x['counties'][0]['name']
#     if not isinstance(x, list):
#         data[i]['counties'] = [x]
result = pd.json_normalize(data, 'counties', ['state', 'shortname'])
print(result)
# Out:
#          name  population    state shortname
# 0        Dade       12345  Florida        FL
# 1     Broward       40000  Florida        FL
# 2  Palm Beach       60000  Florida        FL
# 3      Summit        1234     Ohio        OH
# 4    Cuyahoga        1337     Ohio        OH

# %%
import os
char_count = df['char_count'].tolist()
# print(char_count)

# %%
bin = 60
fig = plt.figure(figsize=(50,30))
# plt.margins(0.02)
# fig, ax = plt.subplots(figsize=(50,30))
plt.hist(char_count, bins=bin)
plt.xlabel('Words', fontsize=50, labelpad=100)
plt.ylabel('Frequency', fontsize=50, labelpad=100)
plt.yticks(fontsize=40)
plt.xticks(fontsize=40)
plt.xlim([1,30])
#remove the first tick in x axis

# xticks = ax.xaxis.get_major_ticks()
# xticks[0].label1.set_visible(False)

plt.title('Frequency of \'the number of characters in each vocab\' with bin = {}'.format(bin), fontsize=60)
plt.show()

# %%
a = ['ab', 'd','c','ab','a']

import numpy as np
aa = np.unique(a)
print(aa)
word_char_count = [len(word) for word in aa]
print(word_char_count)
# Out:
# ['a' 'ab' 'c' 'd']
# [1, 2, 1, 1]

# %%
#convert a to list
import ast
a1 = ast.literal_eval(a)
print(type(a1))
print(a1)
# Out:
# <class 'list'>
# ['ab', 'd']

# %%
a2 = ['a1', 'a2', 'a3']
# ab = []
# ab.append(a2)
# ab.append(a)
ab = a1 + a2
print(ab)
# Out:
# ['ab', 'd', 'a1', 'a2', 'a3']
